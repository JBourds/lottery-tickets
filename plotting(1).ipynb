# %%
def check_if_running_on_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

if check_if_running_on_colab():
    # !pip install multiprocess
    from google.colab import drive
    drive.mount('/content/drive/')
    import os

    GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CS5540/Final Project/lottery-tickets'
    GOOGLE_DRIVE_PATH = os.path.join('drive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
    os.chdir(GOOGLE_DRIVE_PATH)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.8 MB/s eta 0:00:00
# ...
# Mounted at /content/drive/

# %%
"""
plotting.ipynb

Likely move to other files after all plots confirmed to work.

Authors: Jordan Bourdeau, Casey Forey
Date Created: 4/30/24
"""
import functools
from importlib import reload
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import os
import tensorflow as tf
from typing import Generator

from src.harness import constants as C
from src.harness import history
from src.harness import load
from src.metrics import experiment_aggregations as e_agg
from src.metrics import trial_aggregations as t_agg

from src.plotting import base_plots as bp
from src.plotting import global_plots as gp

# %%
reload(load)

# Load a small sample for ease of use
batch_directory: str = 'experiments/lenet_300_100_iterative_magnitude_pruning_experiment'
plots_directory: str = os.path.join(C.PLOTS_DIRECTORY, '20_pruning_025_sparse')

print(os.listdir(batch_directory))

summary: history.ExperimentSummary = list(load.get_batch_summaries(batch_directory, max_num_batches=1))[0]
# Out:
# ['batch_0', 'batch_7', 'batch_4', 'batch_3', 'batch_6', 'batch_2', 'batch_5', 'batch_1']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4c3cc4bc8ac2> in <cell line: 9>()
#       7 print(os.listdir(batch_directory))
#       8
# ----> 9 summary: history.ExperimentSummary = list(load.get_batch_summaries(batch_directory, max_num_batches=1))[0]
#
# /content/drive/MyDrive/CS5540/Final Project/lottery-tickets/src/harness/load.py in get_batch_summaries(batch_directory, batch_prefix, batch_data_file, start_batch, max_num_batches)
#      93             batch_summary_file = os.path.join(batch_directory, batch_dir, batch_data_file)
#      94             if not os.path.exists(batch_summary_file):
# ---> 95                 raise FileNotFoundError(f'Could not find summary file at path: {batch_summary_file}')
# ...

# %% [markdown]
# ## Global Plots with Single Summary

# %%
reload(bp)
reload(gp)
reload(history)

early_stopping_iteration: str = os.path.join(plots_directory, 'early_stopping_iteration.png')
gp.plot_early_stopping(summary, save_location=early_stopping_iteration)

# %%
reload(bp)
reload(e_agg)
reload(gp)

early_stopping_test_accuracy: str = os.path.join(plots_directory, 'early_stopping_test_accuracy.png')
gp.plot_best_accuracy_at_early_stopping(summary, train=False, save_location=early_stopping_test_accuracy)

early_stopping_train_accuracy: str = os.path.join(plots_directory, 'early_stopping_train_accuracy.png')
gp.plot_best_accuracy_at_early_stopping(summary, train=True, save_location=early_stopping_train_accuracy)

# %%
reload(C)
reload(gp)

positive_proportion_initial_weights: str = os.path.join(plots_directory, 'positive_proportion_of_initial_weights_200_models.png')
positive_proportion_final_weights: str = os.path.join(plots_directory, 'positive_proportion_of_final_weights_200_models.png')

gp.plot_sign_proportion(summary, use_initial_weights=False, find_positive_proportion=True, save_location=positive_proportion_final_weights)
gp.plot_sign_proportion(summary, use_initial_weights=True, find_positive_proportion=True, save_location=positive_proportion_initial_weights)

gp.plot_sign_proportion(summary, use_initial_weights=False, find_positive_proportion=False)
gp.plot_sign_proportion(summary, use_initial_weights=True, find_positive_proportion=False)

# %%
reload(bp)
reload(gp)

dual_masked_weights_magnitude: str = os.path.join(plots_directory, 'dual_masked_weights_magnitude.png')
initial_masked_weights_magnitude: str = os.path.join(plots_directory, 'initial_masked_weights_magnitude.png')
final_masked_weights_magnitude: str = os.path.join(plots_directory, 'final_masked_weights_magnitude.png')

gp.plot_average_magnitude(summary, plot_both=True, save_location=dual_masked_weights_magnitude)
gp.plot_average_magnitude(summary, use_initial_weights=True, save_location=initial_masked_weights_magnitude)
gp.plot_average_magnitude(summary, use_initial_weights=False, save_location=final_masked_weights_magnitude)

# %%
reload(bp)
reload(gp)

loss_before_training: str = os.path.join(plots_directory, 'loss_before_training.png')
gp.plot_loss_before_training(summary, save_location=loss_before_training)

# %%
reload(bp)
reload(gp)

accuracy_before_training: str = os.path.join(plots_directory, 'accuracy_before_training.png')
gp.plot_accuracy_before_training(summary, save_location=accuracy_before_training)

# %%
# Work in progress plotting distribution of weights

# reload(history)

# trial = summary.experiments[0].trials[0]
# density, bins = trial.get_weight_density(use_initial_weights=False)

# # Plot the density
# plt.figure()
# plt.hist(bins[:-1], bins, weights=density, density=True, alpha=0.7, color='blue', edgecolor='black')

# # Set labels and title
# plt.title('Density Plot of Weights')
# plt.xlabel('Weight Value')
# plt.ylabel('Density')

# # Show plot
# plt.show()

# %% [markdown]
# ## Global Plots Aggregated Across Batches

# %%
reload(load)

# Load a small sample for ease of use
batch_directory: str = 'experiments/lenet_300_100_iterative_magnitude_pruning_experiment'
plots_directory: str = os.path.join(C.PLOTS_DIRECTORY, '20_pruning_025_sparsity')

print(os.listdir(batch_directory))

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)

early_stopping_batch: str = os.path.join(plots_directory, 'early_stopping_200_models.png')
gp.plot_early_stopping_batch(summaries, early_stopping_batch)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)

best_accuracy_batch: str = os.path.join(plots_directory, 'best_accuracy_200_models.png')
gp.plot_best_accuracy_at_early_stopping_batch(summaries, save_location=best_accuracy_batch)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)
positive_sign_initial_weights: str = os.path.join(plots_directory, 'positive_sign_initial_weights_200_models.png')
gp.plot_sign_proportion_batch(summaries, use_initial_weights=True, save_location=positive_sign_initial_weights)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)
positive_sign_final_weights: str = os.path.join(plots_directory, 'positive_sign_initial_weights_200_models.png')
gp.plot_sign_proportion_batch(summaries, use_initial_weights=False, save_location=positive_proportion_final_weights)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)
average_magnitude_initial_weights: str = os.path.join(plots_directory, 'average_magnitude_initial_weights_200_models.png')
gp.plot_average_magnitude_batch(summaries, use_initial_weights=True, save_location=average_magnitude_initial_weights)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)
average_magnitude_final_weights: str = os.path.join(plots_directory, 'average_magnitude_final_weights_200_models.png')
gp.plot_average_magnitude_batch(summaries, use_initial_weights=False, save_location=positive_proportion_final_weights)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)

loss_before_training: str = os.path.join(plots_directory, 'loss_before_training_200_models.png')
gp.plot_loss_before_training_batch(summaries, save_location=loss_before_training)

# %%
reload(bp)
reload(gp)

summaries: Generator[history.ExperimentSummary, None, None] = load.get_batch_summaries(batch_directory)

accuracy_before_training: str = os.path.join(plots_directory, 'accuracy_before_training_200_models.png')
gp.plot_accuracy_before_training_batch(summaries, save_location=accuracy_before_training)

# %% [markdown]
# ## Layerwise Plots
